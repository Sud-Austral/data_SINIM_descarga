# %%
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
from selenium.webdriver.firefox.options import Options
import http.client, urllib.request, urllib.parse, urllib.error, base64
import shutil
import datetime
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
import os
import glob
import sys
from selenium.webdriver.common.by import By
import time

import warnings
warnings.filterwarnings('ignore') 

from selenium.webdriver.support.ui import Select


def getDriver():
    options = Options()   
    #options.headless = True
    options.set_preference("browser.download.manager.showWhenStarting", False)
    driver = webdriver.Firefox(options=options)
    driver.set_page_load_timeout("600")
    driver.get("https://datos.sinim.gov.cl/datos_municipales.php")    
    return driver

# %%
driver = getDriver()

# %%
driver.page_source
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head>\n                <!-- Google tag (gtag.js) -->\n<script async="" src="https://www.googletagmanager.com/gtag/js?id=G-JX6PNWSEYQ"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n\n  gtag(\'config\', \'G-JX6PNWSEYQ\');\n</script>\t\t<meta http-equiv="Content-Type" content="text/html; charset=ISO-8859-1">\n\t\t<title>Sistema Nacional de Información Municipal</title>\n\n\t\t<link type="text/css" href="assets/css/style.css" rel="stylesheet" media="screen, projection">\n\t\t<link type="application/rss+xml" href="http://www.gob.cl/feed/" rel="alternate" title="RSS 2.0">\n\t\t<link href="assets/css/featured-list.css" rel="stylesheet" type="text/css">\n\t\t<link type="text/css" rel="stylesheet" href="/assets/css/chosen.css">\n\t\t<link rel="stylesheet" href="assets/js/fancybox/source/jquery.fancybox.css" type="text/css" media="screen">\n\n\t\t<script
# ...

# %%
xpath = '/html/body/section/section/div[6]/div[1]/div[2]'
elements = driver.find_elements(By.XPATH, xpath)

# %%
len(elements)
# Out:
# 1

# %%
i = 1;
for element in elements:
    print(i)
    #print(f"{i}***************{element.text}")
    i += 1
# Out:
# 1

# %%
len(elements[0].text.split("\n"))
# Out:
# 2052

# %%
2052/ 345
# Out:
# 5.947826086956522

# %%
xpathMuni = "/html/body/section/section/div[6]/div[1]/div[1]"
elementsMuni = driver.find_elements(By.XPATH, xpath)

# %%
len(elementsMuni)
# Out:
# 1

# %%
len(driver.find_elements(By.CLASS_NAME,"item_municipio"))
# Out:
# 345

# %%
" ".join(driver.find_elements(By.CLASS_NAME,"item_municipio")[0].text.split(" ")[1:])
# Out:
# 'IQUIQUE'

# %%
comuna = [ " ".join(x.text.split(" ")[1:]) for x in driver.find_elements(By.CLASS_NAME,"item_municipio")]
codigo = [ x.text.split(" ")[0] for x in driver.find_elements(By.CLASS_NAME,"item_municipio")]

# %%
col1 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col2 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[345:690]]
col3 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[690:1035]]
col4 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[1035:1380]] 
col5 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[1380:1725]]
col6 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[1725:2070]]

# %%
col7 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col8 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[345:690]]
col9 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[690:1035]]
col10 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[1035:1380]] 
col11 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[1380:1725]]
col12 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[1725:2070]]

# %%
col13 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col14 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col15 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col16 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]

# %%
col17 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col18 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col19 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col20 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]

# %%
col21 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col22 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col23 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col24 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]

# %%
col25 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col26 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col27 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col28 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]

# %%
col29 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col30 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col31 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col32 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]

# %%
col33 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col34 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col35 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col36 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col37 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col38 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col39 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col40 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col41 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col42 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col43 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col44 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col45 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col46 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col47 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col48 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col49 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col50 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col51 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col52 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col53 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col54 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col55 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col56 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col57 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col58 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col59 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col60 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col61 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col62 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col63 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col64 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col65 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col66 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col67 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col68 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col69 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col70 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col71 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col72 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
col73 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]

# %%
diccionarioMaster = {"comuna":comuna,"codigo":codigo,
                     "Indice de Pobreza CASEN (Última Encuesta Vigente)(% )ISOC001":col1,
                     "Monto Pagado por Pensión Básica de Vejez (PBSV) en el año(M$ )NPBSVM":col2,
                     "Monto Pagado por Pensión Básica Solidaria (PBS) en el año(M$ )NPBS1":col3,
                     "Monto Pagado por Pensión de Invalidez (PBSI) en el año(M$ )NPBSIM":col4,
                     "Número de Beneficiarios de Subsidio Eléctrico en la comuna durante el año(Nº )MSELECT":col5,
                     "Pensiones Básicas Solidarias de Invalidez (PBSI) Pagadas a la comuna(N° )NPBSIA":col6,
                     
                           
                    }

df = pd.DataFrame(diccionarioMaster)
df
# Out:
#             comuna codigo  \
# 0          IQUIQUE  01101
# 1    ALTO HOSPICIO  01107
# 2     POZO ALMONTE  01401
# 3           CAMIÑA  01402
# 4         COLCHANE  01403
# ..             ...    ...
# 340     SAN CARLOS  16301
# 341       COIHUECO  16302
# 342         ÑIQUÉN  16303
# 343     SAN FABIÁN  16304
# 344    SAN NICOLÁS  16305
#
#     Indice de Pobreza CASEN (Última Encuesta Vigente)(% )ISOC001  \
# 0                                                7,90%
# 1                                               15,30%
# 2                                               15,30%
# 3                                               24,00%
# 4                                               22,30%
# ..                                                 ...
# 340                                             13,70%
# 341                                             13,50%
# 342                                             13,80%
# 343                                             15,00%
# ...

# %%
12 * 6 + 2
# Out:
# 74

# %%
//*[@id="next"]

# %%
//*[@id="744-47"]

# %%
xpath_masComunas = '//*[@id="next"]'
xpath_siguiente = '//*[@id="go-next"]/span'

# %%
driver.find_element(By.XPATH, xpath_masComunas).click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 driver.find_element(By.XPATH, xpath_masComunas).click()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# ...

# %%
driver.find_element(By.XPATH, xpath_siguiente).click()

# %%
for i in range(13,74):
    print(f'col{i} = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]')
# Out:
# col13 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col14 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col15 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col16 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col17 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col18 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col19 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col20 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col21 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col22 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col23 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# col24 = [x.text for x in driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]]
# ...

# %%
for i in driver.find_elements(By.CLASS_NAME,"item_municipio"):
    print(i.text)
# Out:
# 01101 IQUIQUE
# 01107 ALTO HOSPICIO
# 01401 POZO ALMONTE
# 01402 CAMIÑA
# 01403 COLCHANE
# 01404 HUARA
# 01405 PICA
# 02101 ANTOFAGASTA
# 02102 MEJILLONES
# 02103 SIERRA GORDA
# 02104 TALTAL
# 02201 CALAMA
# 02202 OLLAGÜE
# 02203 SAN PEDRO DE ATACAMA
# 02301 TOCOPILLA
# 02302 MARÍA ELENA
# 03101 COPIAPÓ
# 03102 CALDERA
# 03103 TIERRA AMARILLA
# 03201 CHAÑARAL
# 03202 DIEGO DE ALMAGRO
# 03301 VALLENAR
# 03302 ALTO DEL CARMEN
# 03303 FREIRINA
# 03304 HUASCO
# 04101 LA SERENA
# 04102 COQUIMBO
# 04103 ANDACOLLO
# 04104 LA HIGUERA
# 04105 PAIGUANO
# 04106 VICUÑA
# 04201 ILLAPEL
# 04202 CANELA
# 04203 LOS VILOS
# 04204 SALAMANCA
# 04301 OVALLE
# 04302 COMBARBALÁ
# 04303 MONTE PATRIA
# 04304 PUNITAQUI
# 04305 RÍO HURTADO
# 05101 VALPARAÍSO
# 05102 CASABLANCA
# 05103 CONCÓN
# 05104 JUAN FERNÁNDEZ
# 05105 PUCHUNCAVÍ
# 05107 QUINTERO
# 05109 VIÑA DEL MAR
# 05201 ISLA DE PASCUA
# 05301 LOS ANDES
# 05302 CALLE LARGA
# 05303 RINCONADA
# 05304 SAN ESTEBAN
# 05401 LA LIGUA
# 05402 CABILDO
# ...

# %%
#diccionarioData = 
print(len(driver.find_elements(By.CLASS_NAME,"item_dato")[0:345]))
print(len(driver.find_elements(By.CLASS_NAME,"item_dato")[345:690]))
print(len(driver.find_elements(By.CLASS_NAME,"item_dato")[690:1035]))
print(len(driver.find_elements(By.CLASS_NAME,"item_dato")[1035:1380] ))  
print(len(driver.find_elements(By.CLASS_NAME,"item_dato")[1380:1725]))
print(len(driver.find_elements(By.CLASS_NAME,"item_dato")[1725:2070]  ))
# Out:
# 345
# 345
# 345
# 345
# 345
# 345

# %%
for i in driver.find_elements(By.CLASS_NAME,"fancybox"):
    print(i.text)
    print("##############################################")
# Out:
# ##############################################
# Número Total de Beneficiarios según Plan de Salud FONASA (RSH)
# (N° )
# RSHNFONASA
# ##############################################
# Número Total de Beneficiarios según Plan de Salud ISAPRE (RSH)
# (N° )
# RSHNISAPRE
# ##############################################
# Monto Total (M$) por el Primer Retiro del 10% de los Fondos de Pensiones
# (M$ )
# RETIRO10M1
# ##############################################
# Monto Total (M$) por el Segundo Retiro del 10% de los Fondos de Pensiones
# (M$ )
# RETIRO10M2
# ##############################################
# Monto Total (M$) por el Tercer Retiro del 10% de los Fondos de Pensiones
# (M$ )
# RETIRO10M3
# ##############################################
# Número de Personas que realizaron Primer Retiro del 10% de sus Fondos de Pensiones
# (Nº )
# RETIRO10N1
# ##############################################

# %%
2070/345
# Out:
# 6.0

# %%
for i in range(0,2070,345):
    print(i)
# Out:
# 0
# 345
# 690
# 1035
# 1380
# 1725
